# %%
from numpy.ma.extras import average

FN = "Darius-13-100m-Fly.txt"
FOLDER = "swimdata/"

with open(FOLDER+FN) as file:
    lines = file.readlines()

    print(lines)
    print(type(lines[0]))

    times = lines[0].split(",")
    print(times)
# Out:
# ['1:27.95,1:21.07,1:30.96,1:23.22,1:27.95,1:28.30\n']
# <class 'str'>
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30\n']

# %%
first = times[0]

minutes, rest = first.split(":")
seconds, hundredths = rest.split(".")

converted_time = (int(minutes) * 60 * 100) + (int(seconds) * 100) + int(hundredths)
print(converted_time)
# Out:
# 8795

# %%
for t in times:
    print(t)
# Out:
# 1:27.95
# 1:21.07
# 1:30.96
# 1:23.22
# 1:27.95
# 1:28.30

# %%
import statistics
fn = "Darius-13-100m-Fly.txt"
swimmer, age, distance , stoke = fn.removesuffix("text").split("-")
converts = []

for t in times:
    minutes, rest = t.split(":")
    seconds, hundredths = rest.split(".")
    converts.append((int (minutes)*60+100) + (int(seconds)*100)+ int(hundredths))
    #print(converts)
    statistics.mean(converts)
    average = statistics.mean(converts)
    mins_secs, hundredths =str(round(average / 100,2))
    mins_secs = int(mins_secs)
    minutes = mins_secs // 60
    print(minutes)
    seconds = mins_secs - minutes * 60
    print(seconds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 swimmer, age, distance , stoke = fn.removesuffix("text").split("-")
#       4 converts = []
# ----> 6 for t in times:
#       7     minutes, rest = t.split(":")
#       8     seconds, hundredths = rest.split(".")
#
# NameError: name 'times' is not defined

# %%
converts = []
print(type(converts))
print(len(converts))
print (dir(converts))
# Out:
# <class 'list'>
# 0
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
help(converts.append)
# Out:
# Help on built-in function append:
#
# append(object, /) method of builtins.list instance
#     Append object to the end of the list.
